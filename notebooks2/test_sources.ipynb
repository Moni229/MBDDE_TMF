# %%
# ==========================================
# Configuración
# ==========================================

FRED_API_KEY = "5b99efb70795b9131431bdc248a8053c"
FINNHUB_API_KEY = "d8k5659r01qjgd6rh780d8k5659r01qjgd6rh78g"

# %%
from databricks.sdk import WorkspaceClient
w = WorkspaceClient()
secrets = w.secrets.get_secret(scope='macroeconomy', key='FRED-API-KEY')
print(secrets)
