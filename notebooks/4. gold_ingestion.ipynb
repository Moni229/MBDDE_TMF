# %%
dbutils.library.restartPython()

# %%
# %pip install --force-reinstall ./macroeconomy-0.1.0-py3-none-any.whl

# %%
from macroeconomy.readers.delta_reader import DeltaReader
from macroeconomy.writers.delta_writer import DeltaWriter
from macroeconomy.pipelines.gold_pipeline import GoldPipeline

pipeline = GoldPipeline(spark)
pipeline.run("fact_macro")

# %%
display(spark.sql("select * from macroeconomy_gold.fact_market_macro limit 100"))

# %%
display(spark.sql("select distinct symbol from macroeconomy_gold.fact_macro limit 100"))

# %%
spark.sql("drop table macroeconomy_gold.fact_market_macro")

# %%
# %sql
SELECT
    date,
    value,
    geo
FROM macroeconomy_silver.fred_cpiaucsl
ORDER BY date
LIMIT 30;

# %%
# %sql
SELECT
    date,
    COUNT(*) AS n
FROM macroeconomy_silver.fred_cpiaucsl
GROUP BY date
HAVING COUNT(*) > 1
ORDER BY date;

# %%
# %sql
SELECT
    date,
    COUNT(*) AS n
FROM macroeconomy_silver.fred_cpiaucsl
GROUP BY date
HAVING COUNT(*) > 1
ORDER BY date;
