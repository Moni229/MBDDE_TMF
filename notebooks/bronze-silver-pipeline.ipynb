# %%
# %pip install -e ..

# %%
dbutils.widgets.text("datasource", "")
dbutils.widgets.text("dataset", "")
datasource = dbutils.widgets.get("datasource")
dataset = dbutils.widgets.get("dataset")

# %%
from macroeconomy import setup_lakehouse
setup_lakehouse()

# %%
from macroeconomy.pipelines import BronzePipeline

bronze_pipeline = BronzePipeline(spark)
bronze_pipeline.run(datasource, dataset)

# %%
from macroeconomy.pipelines.silver_pipeline import SilverPipeline

silver_pipeline = SilverPipeline(spark)
silver_pipeline.run(datasource, dataset)
